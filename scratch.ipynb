# %%
import random
failsafe = 0
val = 15
while val is not 0:
    val = random.randrange(0,15)
    failsafe += 1
    if failsafe > 100000:
        break
print(failsafe)
# Out:
# 30

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
img1 = '/Users/blacksek/repos/DogBreedDetector/images/American_water_spaniel_00648.jpg'
img2 = '/Users/blacksek/repos/DogBreedDetector/images/Welsh_springer_spaniel_08203.jpg'

# %%
#https://stackoverflow.com/questions/25124143/matplotlib-subplots-get-rid-of-tick-labels-altogether

# %%
def plot_figures(images, nrows=1, ncols=2):
    img1 = Image.open(images[0])
    img2 = Image.open(images[1])
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
    ax1.imshow(img1)
    ax1.set_title('img 1')
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax2.imshow(img2)
    ax2.set_title('img2')
    ax2.set_xticks([])
    ax2.set_yticks([])
    plt.show()

plot_figures([img1,img2])
